# %%
import subprocess
result = subprocess.run(
    ['python', '-m', 'vfs_appointment_bot.main', '-sc', 'MA', '-dc', 'PT',
     '-ap', 'visa_center=Casablanca,visa_category=Short Stay,visa_sub_category=Tourism'],
    capture_output=True, text=True, timeout=120,
    cwd='/workspaces/vfs-appointment-bot'
)
print('STDOUT:', result.stdout[-3000:] if len(result.stdout) > 3000 else result.stdout)
print('---STDERR---')
print(result.stderr[-3000:] if len(result.stderr) > 3000 else result.stderr)
print('Return code:', result.returncode)
# Out:
# STDOUT: ble-infobars --disable-search-engine-choice-screen --disable-sync --enable-unsafe-swiftshader --headless --hide-scrollbars --mute-audio --blink-settings=primaryHoverType=2,availableHoverTypes=2,primaryPointerType=4,availablePointerTypes=4 --no-sandbox --user-data-dir=/tmp/playwright_chromiumdev_profile-l4ssIb --remote-debugging-pipe --no-startup-window
# <launched> pid=32668
# [pid=32668][err] /home/codespace/.cache/ms-playwright/chromium_headless_shell-1208/chrome-headless-shell-linux64/chrome-headless-shell: error while loading shared libraries: libatk-1.0.so.0: cannot open shared object file: No such file or directory
# Call log:
# ...
